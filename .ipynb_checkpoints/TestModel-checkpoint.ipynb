# %% [markdown]
# # Testing the Model
# Change the variable `text` and **Run** the cell bellow to test the model.

# %%
from model import *

# Change the text to test the model
text = "I wish you all the worst."

# Dataset for normalization data
dataset = HateClassifierDataset('X.csv','y.csv')

# Load Model
classifier = load_model('best_model.pth')

# Show Results
ax = print_probs(classifier, text, dataset)
ax

# %%
# Change the text to test the model
text = "Have a Great day and week!!"

# Show Results
ax = print_probs(classifier, text, dataset)
ax

# %%
# Change the text to test the model
text = "I drink a lot of coconut water. It balances out all the other toxic stuff I put into my body"

# Show Results
ax = print_probs(classifier, text, dataset)
ax
